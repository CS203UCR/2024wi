# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras import layers

def representative_dataset():
    for _ in range(100):
       data = np.append(np.random.randint(2,size=16),np.random.randint(256,size=1))
#      data = np.random.rand(1, 25)
       yield [data.astype(np.float32)]

training_x = []
training_y = []
training_size = 20000
for x in range(training_size):
    a = np.random.randint(2,size=16)
    b = np.random.randint(2,size=8)
    a = np.reshape(a, (4,4))
    b = np.reshape(b, (4,2))
#    print(a)
#    print(b)
    c = np.matmul(a,b)
    c = np.where(c>1, 1, 0)
#    print(c)
    a= np.reshape(a, (16))
    b= np.reshape(b, (8))
    c= np.reshape(c, (8))
    result = 0
    for y in range(8):
        result = (result << 1) + c[y]
#    result = result - 128
    result = result
    training_x = np.append(training_x,np.append(a,b))
#    print(training_x.shape)
    training_y = np.append(training_y,result)
#    print(training_y)
training_x = np.reshape(training_x,(training_size,24))
#print(training_x)
training_y = np.reshape(training_y,(training_size,1))
#print(training_y)
#print(training_y)

validation_x = []
validation_y = []
for x in range(2000):
    a = np.random.randint(2,size=16)
    b = np.random.randint(2,size=8)
    a = np.reshape(a, (4,4))
    b = np.reshape(b, (4,2))
    c = np.matmul(a,b)
    c = np.where(c>1, 1, 0)
    a= np.reshape(a, (16))
    b= np.reshape(b, (8))
    c= np.reshape(c, (8))
    result = 0
    for y in range(8):
        result = (result << 1) + c[y]
    result = result
    validation_x = np.append(validation_x,np.append(a,b))
    validation_y = np.append(validation_y,result)
validation_x = np.reshape(validation_x,(2000,24))
validation_y = np.reshape(validation_y,(2000,1))

#inputs = keras.Input(shape=(24,), name="digits")
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(24,)),
  tf.keras.layers.Dense(576, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(1)
])
#x = layers.Dense(256, activation="relu", name="dense_1")(inputs)
#x = layers.Dense(256, activation="relu", name="dense_2")(x)
#x = layers.Dense(128, activation="relu", name="dense_3")(x)
#x = layers.Dense(32, activation="relu", name="dense_4")(x)
#x = layers.Dense(32, activation="relu", name="dense_5")(x)
#outputs = layers.Dense(1, activation="softmax", name="predictions")(x)

#model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
#model.compile(
#    optimizer=keras.optimizers.RMSprop(),  # Optimizer
    # Loss function to minimize
#    loss=keras.losses.SparseCategoricalCrossentropy(),
    # List of metrics to monitor
#    metrics=[keras.metrics.SparseCategoricalAccuracy()],
#)
print("Fit model on training data")
history = model.fit(
    training_x,
    training_y,
    batch_size=32,
    epochs=16,
    # We pass some validation for
    # monitoring validation loss and metrics
    # at the end of each epoch
    validation_data=(validation_x, validation_y),
)
#print(history)
#Save as Keras
model.save("bmm_npu.keras")
#print(validation_x[0])
#np.append(validation_y[0],validation_x[0])
#print(representative_dataset)
#print(representative_dataset.shape)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [
tf.lite.OpsSet.TFLITE_BUILTINS_INT8, # enable TensorFlow Lite ops.
tf.lite.OpsSet.TFLITE_BUILTINS, # enable TensorFlow Lite ops.
tf.lite.OpsSet.SELECT_TF_OPS # enable TensorFlow ops.
]
converter.target_spec.supported_types = [tf.int8]
converter.inference_input_type = tf.int8 # or tf.uint8
converter.inference_output_type = tf.int8 # or tf.uint8
converter.experimental_new_quantizer = True # It will enable conversion and quantization of MLIR ops
converter.experimental_new_converter = False
tflite_model = converter.convert()
# Save the model as a TFLite model.
with open('bmm_npu.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# Fit model on training data
# Epoch 1/16
# 625/625 [==============================] - 1s 869us/step - loss: nan - sparse_categorical_accuracy: 0.2215 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 2/16
# 625/625 [==============================] - 0s 733us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 3/16
# 625/625 [==============================] - 0s 749us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 4/16
# 625/625 [==============================] - 0s 755us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 5/16
# 625/625 [==============================] - 0s 740us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 6/16
# 625/625 [==============================] - 0s 769us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 7/16
# 625/625 [==============================] - 0s 716us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 8/16
# 625/625 [==============================] - 0s 751us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 9/16
# 625/625 [==============================] - 0s 706us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 10/16
# 625/625 [==============================] - 0s 741us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 11/16
# 625/625 [==============================] - 0s 750us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 12/16
# 625/625 [==============================] - 0s 705us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 13/16
# 625/625 [==============================] - 0s 686us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 14/16
# 625/625 [==============================] - 0s 728us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 15/16
# 625/625 [==============================] - 0s 736us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# Epoch 16/16
# 625/625 [==============================] - 0s 748us/step - loss: nan - sparse_categorical_accuracy: 0.2217 - val_loss: nan - val_sparse_categorical_accuracy: 0.2240
# INFO:tensorflow:Assets written to: /tmp/tmpalxq7qr_/assets
# INFO:tensorflow:Assets written to: /tmp/tmpalxq7qr_/assets
# 2024-01-18 09:11:05.818332: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:05.818417: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2024-01-18 09:11:05.818461: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2024-01-18 09:11:05.818611: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:05.818662: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:05.818699: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:05.818764: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:05.818802: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:05.818840: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10189 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2024-01-18 09:11:05.838770: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:05.838832: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2024-01-18 09:11:05.838864: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2024-01-18 09:11:05.839049: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:05.839096: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:05.839133: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:05.839188: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:05.839226: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:05.839257: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10189 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# WARNING:absl:Please consider switching to the new converter by setting experimental_new_converter=True. The old converter is deprecated.
# /opt/jupyterhub/lib/python3.8/site-packages/tensorflow/lite/python/convert.py:765: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# ---------------------------------------------------------------------------
# ConverterError                            Traceback (most recent call last)
# Cell In [113], line 127
#     125 converter.experimental_new_quantizer = True # It will enable conversion and quantization of MLIR ops
#     126 converter.experimental_new_converter = False
# --> 127 tflite_model = converter.convert()
#     128 # Save the model as a TFLite model.
#     129 with open('bmm_npu.tflite', 'wb') as f:
#
# File /opt/jupyterhub/lib/python3.8/site-packages/tensorflow/lite/python/lite.py:933, in _export_metrics.<locals>.wrapper(self, *args, **kwargs)
#     930 @functools.wraps(convert_func)
#     931 def wrapper(self, *args, **kwargs):
#     932   # pylint: disable=protected-access
# --> 933   return self._convert_and_export_metrics(convert_func, *args, **kwargs)
#
# File /opt/jupyterhub/lib/python3.8/site-packages/tensorflow/lite/python/lite.py:911, in TFLiteConverterBase._convert_and_export_metrics(self, convert_func, *args, **kwargs)
#     909 self._save_conversion_params_metric()
#     910 start_time = time.process_time()
# --> 911 result = convert_func(self, *args, **kwargs)
#     912 elapsed_time_ms = (time.process_time() - start_time) * 1000
#     913 if result:
#
# File /opt/jupyterhub/lib/python3.8/site-packages/tensorflow/lite/python/lite.py:1352, in TFLiteKerasModelConverterV2.convert(self)
#    1346 graph_def, input_tensors, output_tensors, frozen_func = (
#    1347     self._freeze_keras_model())
#    1349 graph_def = self._optimize_tf_model(graph_def, input_tensors,
#    1350                                     output_tensors, frozen_func)
# -> 1352 return super(TFLiteKerasModelConverterV2,
#    1353              self).convert(graph_def, input_tensors, output_tensors)
#
# File /opt/jupyterhub/lib/python3.8/site-packages/tensorflow/lite/python/lite.py:1135, in TFLiteConverterBaseV2.convert(self, graph_def, input_tensors, output_tensors)
#    1130   logging.info("Using new converter: If you encounter a problem "
#    1131                "please file a bug. You can opt-out "
#    1132                "by setting experimental_new_converter=False")
#    1134 # Converts model.
# -> 1135 result = _convert_graphdef(
#    1136     input_data=graph_def,
#    1137     input_tensors=input_tensors,
#    1138     output_tensors=output_tensors,
#    1139     **converter_kwargs)
#    1141 return self._optimize_tflite_model(
#    1142     result, self._quant_mode, quant_io=self.experimental_new_quantizer)
#
# File /opt/jupyterhub/lib/python3.8/site-packages/tensorflow/lite/python/convert_phase.py:212, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     210   else:
#     211     report_error_message(str(converter_error))
# --> 212   raise converter_error from None  # Re-throws the exception.
#     213 except Exception as error:
#     214   report_error_message(str(error))
#
# File /opt/jupyterhub/lib/python3.8/site-packages/tensorflow/lite/python/convert_phase.py:205, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     202 @functools.wraps(func)
#     203 def wrapper(*args, **kwargs):
#     204   try:
# --> 205     return func(*args, **kwargs)
#     206   except ConverterError as converter_error:
#     207     if converter_error.errors:
#
# File /opt/jupyterhub/lib/python3.8/site-packages/tensorflow/lite/python/convert.py:793, in convert_graphdef(input_data, input_tensors, output_tensors, **kwargs)
#     790   else:
#     791     model_flags.output_arrays.append(util.get_tensor_name(output_tensor))
# --> 793 data = convert(
#     794     model_flags.SerializeToString(),
#     795     conversion_flags.SerializeToString(),
#     796     input_data.SerializeToString(),
#     797     debug_info_str=debug_info.SerializeToString() if debug_info else None,
#     798     enable_mlir_converter=enable_mlir_converter)
#     799 return data
#
# File /opt/jupyterhub/lib/python3.8/site-packages/tensorflow/lite/python/convert.py:312, in convert(model_flags_str, conversion_flags_str, input_data_str, debug_info_str, enable_mlir_converter)
#     309       converter_error.append_error(error_data)
#     310     raise converter_error
# --> 312 return _run_deprecated_conversion_binary(model_flags_str,
#     313                                          conversion_flags_str, input_data_str,
#     314                                          debug_info_str)
#
# File /opt/jupyterhub/lib/python3.8/site-packages/tensorflow/lite/python/convert_phase.py:212, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     210   else:
#     211     report_error_message(str(converter_error))
# --> 212   raise converter_error from None  # Re-throws the exception.
#     213 except Exception as error:
#     214   report_error_message(str(error))
#
# File /opt/jupyterhub/lib/python3.8/site-packages/tensorflow/lite/python/convert_phase.py:205, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     202 @functools.wraps(func)
#     203 def wrapper(*args, **kwargs):
#     204   try:
# --> 205     return func(*args, **kwargs)
#     206   except ConverterError as converter_error:
#     207     if converter_error.errors:
#
# File /opt/jupyterhub/lib/python3.8/site-packages/tensorflow/lite/python/convert.py:416, in _run_deprecated_conversion_binary(model_flags_str, conversion_flags_str, input_data_str, debug_info_str)
#     414     stdout = _try_convert_to_unicode(stdout)
#     415     stderr = _try_convert_to_unicode(stderr)
# --> 416     raise ConverterError("See console for info.\n%s\n%s\n" % (stdout, stderr))
#     417 finally:
#     418   # Must manually cleanup files.
#     419   for filename in [
#     420       conversion_filename, input_filename, model_filename, output_filename
#     421   ]:
#
# ConverterError: See console for info.
# 2024-01-18 09:11:07.756655: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:07.773585: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:07.773677: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-18 09:11:07.775161: F tensorflow/lite/toco/import_tensorflow.cc:2770] Check failed: status.ok() Neither input_content (0) nor int_val (0) have the right dimensions (1) for this int32 tensor
# 	 (while processing node 'sequential_12/dense_24/Tensordot/GatherV2/axis')
# Fatal Python error: Aborted
#
# Current thread 0x00007f2ea7fda740 (most recent call first):
#   File "/nfshome/htseng/.local/lib/python3.8/site-packages/tensorflow/lite/toco/python/toco_from_protos.py", line 50 in execute
#   File "/nfshome/htseng/.local/lib/python3.8/site-packages/absl/app.py", line 258 in _run_main
#   File "/nfshome/htseng/.local/lib/python3.8/site-packages/absl/app.py", line 312 in run
#   File "/nfshome/htseng/.local/lib/python3.8/site-packages/tensorflow/lite/toco/python/toco_from_protos.py", line 93 in main
#   File "/usr/local/bin/toco_from_protos", line 8 in <module>
# Aborted (core dumped)
